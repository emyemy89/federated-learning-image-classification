# %%
import torch
from torchvision import datasets, transforms
import torch.nn as nn

# %%
# We will need to convert image to tensors
# here we define a transform
transform = transforms.ToTensor()

# %%
# load the dataset
# now each image mnist_trainset[i][0] is a tensor of shape [1, 28, 28] (1 channel, 28×28 pixels)
mnist_trainset=datasets.MNIST(root = './data', train = True, download = True, transform = transform)
mnist_testset=datasets.MNIST(root = './data', train = False, download = True, transform = transform)

# %%
#len(mnist_trainset) len(mnist_testset)

# %%
image, label = mnist_trainset[0]

print(type(image))
print(image.shape)
print(label)
# Out:
# <class 'torch.Tensor'>
# torch.Size([1, 28, 28])
# 5

# %%
# next we implment the CNN
# a CNN with 2 layers: Layer1-> Relu->Pool->Layer2->...->Flatten->Fully connected->Output

# First layer
conv1 = nn.Conv2d(in_channels=1,   # Mnist has 1 channel
                  out_channels=16, # 16 filters
                  kernel_size=3)   # 3x3 kernel size
out = conv1(x)
# print(out.shape) # torch.Size([1, 16, 26, 26])
relu = nn.ReLU()
pool = nn.MaxPool2d(kernel_size=2)
out = relu(out)
out = pool(out) # reduces size by half, 26->13
# print(out.shape) # torch.Size([1, 16, 13, 13])

# Second layer
conv2 = nn.Conv2d(in_channels=16,   # Mnist has 1 channel
                  out_channels=32, # 16 filters
                  kernel_size=3)   # 3x3 kernel size
out = conv2(out)
# print(out.shape) # torch.Size([1, 32, 11, 11])
out = relu(out)
out = pool(out) # reduces size by half, 11->5
# print(out.shape) # torch.Size([1, 32, 5, 5])

# Now Flatten
out = out.view(out.size(0), -1) # here we reshape the tensor to be of 'out.size(0)' rows 
                                # but don't know exactly how many columns, so we specify '-1'
                                # [1, 32, 5, 5] -> [1, 800]
# create the fully connected layer
fully_connected = nn.Linear(800,10)
out = fully
